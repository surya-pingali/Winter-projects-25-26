# %% [markdown]
# Assignment 0 | Formation based UAV Path-Planning

# %% [markdown]
# # Submission Guidelines Github
# Make a copy of this notebook then solve. The name of the solution file should be strictly :- **ProjectName_Rollno_FullName**
#
# Firstly, download the solution notebook in ipynb format, then upload in your forked repository in **Assignment_0 folder** then open pull request as specified on the community group. Note that if your notebook size is greater than 25MB then please reduce it as github only allows file size less than 25MB per upload. You can clear output cell of question 2 solution (only if output plot is taking much space) to reduce size.
#
# Project Repo:-
# https://github.com/electricalengineersiitk/Winter-projects-25-26/tree/main/Formation-Based%20UAV%20Path%20Planning
#
# **DEADLINE : 12 DECEMBER EOD**
#
# Please refrain from using any AI tools. All the work should be your own

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install numpy matplotlib ipython
# Out:
# Requirement already satisfied: pip in c:\users\morta\downloads\c++\.venv\lib\site-packages (25.3)
# Requirement already satisfied: numpy in c:\users\morta\downloads\c++\.venv\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\morta\downloads\c++\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: ipython in c:\users\morta\downloads\c++\.venv\lib\site-packages (9.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\morta\downloads\c++\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from jedi>=0.18.1->ipython) (0.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\morta\downloads\c++\.venv\lib\site-packages (from stack_data>=0.6.0->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\morta\downloads\c++\.venv\lib\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %% [markdown]
# ## Question 1:
#
# Consider the flower petal $r(\theta) = 1+3\sin(6 \theta)$ for $0 \leq \theta \leq 2 \pi$
#
# 1. Make a plot of the flower (find x and y points)
#
# 2. Implement the formulas that you studied in MTH 112 to calculate area and arclength (Do not use any in built functions)

# %% [markdown]
# ## Your Solution 1

# %%
# plot
theta = np.linspace(0, 2*np.pi, 20001)
r = 1 + 3*np.sin(6*theta)

x = r * np.cos(theta)
y = r * np.sin(theta)
plt.figure(figsize=(5,5))
plt.plot(x, y)
plt.axis('equal')
plt.title("Q1: r(θ)=1 + 3 sin(6θ)")
plt.show()

# %%
# area and arclength

area = 0.5 * np.trapz(r**2, theta)
dr_dtheta = np.gradient(r, theta)
arc_length = np.trapz(np.sqrt(r**2 + dr_dtheta**2), theta)

print(f"Q1 — Area = {area:.6f}")
print(f"Q1 — Arc length = {arc_length:.6f}")
# Out:
# Q1 — Area = 17.278760
# Q1 — Arc length = 74.947577
# C:\Users\morta\AppData\Local\Temp\ipykernel_24988\3106799175.py:3: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   area = 0.5 * np.trapz(r**2, theta)
# C:\Users\morta\AppData\Local\Temp\ipykernel_24988\3106799175.py:5: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   arc_length = np.trapz(np.sqrt(r**2 + dr_dtheta**2), theta)

# %% [markdown]
# ## Question 2
# You are given coordinates of 98 drones representing a closed shape. The drones must follow that path for a show. By using those points plot the epicycle approximation of that shape so that drones can be programmed for that path. (You can use the reference code to draw epicycles in the notebook that we sent you as a resource)
#
# $Position = \{ \ (0,\, 5),(\pm 0.356,\, 4.987),(\pm 0.66,\, 4.96),(\pm 0.98,\, 4.90),(\pm 1.27,\, 4.84),(\pm 2.3,\, 6),(\pm 2.6,\, 7.1),(\pm 3.33,\, 8.49),(\pm 3.91,\, 8.79),(\pm 4.48,\, 8.95),(\pm 5.22,\, 8.99),(\pm 5.90,\, 8.86),(\pm 6.68,\, 8.48),(\pm 7.25,\, 7.98),(\pm 7.64,\, 7.41),
 (-5.55, 3.05),
 (-7.2, 3.96),
 (-7.86, 5.11),
 (-8, 6),
 (-7.9, 6.76),
 (-7.64, 7.41),
 (-7.25, 7.98),
 (-6.68, 8.48),
 (-5.9, 8.86),
 (-5.22, 8.99),
 (-4.48, 8.95),
 (-3.91, 8.79),
 (-3.33, 8.49),
 (-2.6, 7.3),
 (-2.3, 6),
 (-1.27, 4.84),
 (-0.98, 4.9),
 (-0.66, 4.96),
 (-0.356, 4.987)])

len(points)
# Out:
# 98

# %% [markdown]
# ### 2.1) Plot the points using matplotlib. What shape did you noticed ?

# %% [markdown]
# ### 2.2) Plot the epicyclic approximation of this shape. Assume all the points of this shape are (xn,yn) means there are n circles having radii $R_i$, angular frequency $w_i$ and phase $\phi_i$ (from i = 1 to n) representing the given shape
#
# $$
# x_n = \sum_{i=1}^{n} R_i \cos(\omega_i t + \phi_i), \qquad
# y_n = \sum_{i=1}^{n} R_i \sin(\omega_i t + \phi_i)
# $$
#
# We can generalize it as a complex number
#
# $$z_n = \sum_{i=1}^n R_i e^{ j (\omega_i t + \phi_i) } = \sum_{i=1}^n C_i e^{ j (\omega_i t)}$$
#
# where  $j = \sqrt{-1}$   and   $C_ie^{j \omega_i t}$ represents a circle of radii $R_i$, angular frequency $w_i$ and phase $\phi_i$

# %% [markdown]
# ## Hints Q2
# It will be difficult to derive the formula to calculate $C_i$ for each term. So, here's the in built function for that. (It requires the knowledge of Fourier transforms which some of you will study in 2nd year and its currently out of scope)

# %%
# First convert each point into a complex number then use the below code to calculate R_i , w_i and phi_i via C_i
# N = 98 drones
C = np.fft.fft(z)/N #where z is the array of complex numbers of points
w = 2*np.pi*(np.fft.fftfreq(N, d=1/N))
#Ri is magnitude of Ci
#phi_i is angle of Ci

# %% [markdown]
# ## Your Solution 2

# %%
#1

plt.figure(figsize=(5,5))
plt.plot(points[:,0], points[:,1], '.', markersize=4)   # scatter
plt.axis('equal')
plt.title("Q2(a): Raw 98 points")
plt.show()

# %%
#2

z = points[:,0] + 1j*points[:,1]
C = np.fft.fft(z)
mag = np.abs(C)
Ks = [6, 12, 30]

plt.figure(figsize=(12,4))
for i,K in enumerate(Ks,1):
    idx = np.argsort(mag)[-K:]
    C_filt = np.zeros_like(C); C_filt[idx] = C[idx]
    z_approx = np.fft.ifft(C_filt)
    rms = np.linalg.norm(z - z_approx) / np.sqrt(len(z))
    ax = plt.subplot(1, len(Ks), i)
    ax.plot(points[:,0], points[:,1], '.', markersize=3, label='original')
    ax.plot(z_approx.real, z_approx.imag, '-', linewidth=1, label=f'K={K}')
    ax.set_aspect('equal', 'box')
    ax.set_title(f'K={K}  RMS={rms:.4f}')
    ax.axis('off')
plt.tight_layout()
plt.show()

# Print RMS values cleanly
for K in Ks:
    idx = np.argsort(mag)[-K:]
    C_filt = np.zeros_like(C); C_filt[idx] = C[idx]
    z_approx = np.fft.ifft(C_filt)
    rms = np.linalg.norm(z - z_approx) / np.sqrt(len(z))
    print(f"K={K:2d}  RMS = {rms:.6f}")
# Out:
# K= 6  RMS = 0.932677
# K=12  RMS = 0.380553
# K=30  RMS = 0.133558

# %% [markdown]
# ## Question 3
# The energy required to get from point $\vec{r}_1$ to point $\vec{r}_2$ for a drone is given by
#
# $$ E = \alpha \int_{C} \left| \frac{d\vec{r}}{dt} \right| dt - \int_C \vec{F} \cdot \frac{d\vec{r}}{dt}dt $$

# %% [markdown]
# 3.1) Suppose that $\alpha=5$ and our start and ends points are $\vec{r}_1 = (0,0)$ and $\vec{r}_2 = (0, 10)$. On this particular day, the wind produces a force field $\vec{F} = (0, -2/(x+1)^2)$. Approximate the optimal value of $A$ (A>0) in $\vec{r}(t) = A\sin(\pi t/10)\hat{x} + t\hat{y}$ that minimizes the **work** using only numpy arrays .

# %% [markdown]
# 3.2) Plot Energy as a function of A . (E(A) v/s A ) ? (Comment about its shape)

# %% [markdown]
# ## Your Solution 3

# %%
#1
alpha = 5.0

def E_of_A(A):
    t = np.linspace(0, 10, 10001)
    x = A * np.sin(np.pi * t / 10)
    dx = A * (np.pi/10) * np.cos(np.pi * t / 10)
    dy = np.ones_like(t)

    term1 = alpha * np.trapz(np.sqrt(dx*dx + dy*dy), t)
    Fy = -2.0 / (x + 1.0)**2
    work = np.trapz(Fy * dy, t)

    return term1 - work

Agrid = np.linspace(0, 5, 501)
Egrid = np.array([E_of_A(a) for a in Agrid])
Amin = Agrid[np.argmin(Egrid)]

af = np.linspace(max(0, Amin - 0.3), min(5, Amin + 0.3), 2001)
Ef = np.array([E_of_A(a) for a in af])

Amin_ref = af[np.argmin(Ef)]
Emin_ref = Ef.min()

print("A_min =", Amin_ref)
print("E_min =", Emin_ref)
# Out:
# C:\Users\morta\AppData\Local\Temp\ipykernel_24988\274481330.py:10: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   term1 = alpha * np.trapz(np.sqrt(dx*dx + dy*dy), t)
# C:\Users\morta\AppData\Local\Temp\ipykernel_24988\274481330.py:12: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   work = np.trapz(Fy * dy, t)
# A_min = 1.4258
# E_min = 59.166850327932

# %%
#2
plt.plot(Agrid, Egrid, label="coarse")
plt.plot(af, Ef, label="refined")
plt.scatter([Amin_ref], [Emin_ref], color='red')
plt.legend()
plt.show()

# %% [markdown]
# ## Question 4
#
# You decide to install a series of camera drones along a straight path to spy on a suspicious person located at marker 31
#
# You buy four drones and they are evenly spaced starting from mile marker 16 and ending on mile marker 25.
#
# You buy another four drones starting on mile marker 29 and ending on mile marker 34. (also evenly spaced)
#
# A drone can face only one direction at a time.
# In order, from marker 16 to 34, each drone's orientation : N,S,E,W,S,E,W,N. (where N,S,E,W are cardinal directions)
#
# Determine how far each drone facing E is from the person? (Solve using Numpy only)

# %% [markdown]
# ## Your Solution 4

# %%
person = 31.0
g1 = np.linspace(16,25,4)
g2 = np.linspace(29,34,4)
pos = np.concatenate([g1,g2])
ori = np.array(['N','S','E','W','S','E','W','N'])

east = pos[ori=='E']
dist = np.abs(east - person)

for p,d in zip(east, dist):
    print(f"{p:.6f}  {d:.6f}")
# Out:
# 22.000000  9.000000
# 30.666667  0.333333
