# %% [markdown]
# Assignment 0 | Formation based UAV Path-Planning

# %% [markdown]
# # Submission Guidelines Github
# Make a copy of this notebook then solve. The name of the solution file should be strictly :- **ProjectName_Rollno_FullName**
#
# Firstly, download the solution notebook in ipynb format, then upload in your forked repository in **Assignment_0 folder** then open pull request as specified on the community group. Note that if your notebook size is greater than 25MB then please reduce it as github only allows file size less than 25MB per upload. You can clear output cell of question 2 solution (only if output plot is taking much space) to reduce size.
#
# Project Repo:-
# https://github.com/electricalengineersiitk/Winter-projects-25-26/tree/main/Formation-Based%20UAV%20Path%20Planning
#
# **DEADLINE : 12 DECEMBER EOD**
#
# Please refrain from using any AI tools. All the work should be your own

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Question 1:
#
# Consider the flower petal $r(\theta) = 1+3\sin(6 \theta)$ for $0 \leq \theta \leq 2 \pi$
#
# 1. Make a plot of the flower (find x and y points)
#
# 2. Implement the formulas that you studied in MTH 112 to calculate area and arclength (Do not use any in built functions)

# %% [markdown]
# ## Your Solution 1

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 4000, endpoint=True)
r = 1 + 3 * np.sin(6 * theta)
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.figure(figsize=(6,6))
plt.plot(x, y, linewidth=1.0)
plt.gca().set_aspect('equal', 'box')
plt.xlabel('x'); plt.ylabel('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0.0, 2*np.pi, 200000, endpoint=True)   
r = 1 + 3*np.sin(6*theta)
dr = 18*np.cos(6*theta)

area = 11*np.pi/2

integrand = np.sqrt(r**2 + dr**2)
Num = np.trapezoid(integrand, theta)

print("Area :", area)
print("Arc length :", Num)
# Out:
# Area : 17.27875959474386
# Arc length : 74.9476180621357

# %% [markdown]
# ## Question 2
# You are given coordinates of 98 drones representing a closed shape. The drones must follow that path for a show. By using those points plot the epicycle approximation of that shape so that drones can be programmed for that path. (You can use the reference code to draw epicycles in the notebook that we sent you as a resource)
#
# $Position = \{ \ (0,\, 5),(\pm 0.356,\, 4.987),(\pm 0.66,\, 4.96),(\pm 0.98,\, 4.90),(\pm 1.27,\, 4.84),(\pm 2.3,\, 6),(\pm 2.6,\, 7.1),(\pm 3.33,\, 8.49),(\pm 3.91,\, 8.79),(\pm 4.48,\, 8.95),(\pm 5.22,\, 8.99),(\pm 5.90,\, 8.86),(\pm 6.68,\, 8.48),(\pm 7.25,\, 7.98),(\pm 7.64,\, 7.41),(\pm 7.90,\, 6.76),(\pm 8,\, 6),(\pm 7.86,\, 5.11),(\pm 7.20,\, 3.96),(\pm 5.55,\, 3.05),(\pm 4.5,\, 2.18),(\pm 4.65,\, 1.82),(\pm 4.81,\,\pm 1.37),(\pm 4.90,\,\pm 0.98),(\pm 4.96,\, \pm 0.66),(\pm 4.99,\,\pm 0.36),(\pm 5,\, 0),(\pm 5.12,\, -1.66),(\pm 5.20,\, -2.04),(\pm 5.06,\, -2.63),(\pm 4.79,\, -3.11),(\pm 4.55,\, -3.41),(\pm 4.28,\, -3.66),(\pm 3.99,\, -3.87),(\pm 3.68,\, -4.05),(\pm 3.29,\, -4.18),(\pm 3,\, -4.21),(\pm 2.87,\, -4.30),(\pm 2.6,\, -4.48),(\pm 2.33,\, 4.67),(\pm 2.14,\, -4.81),(\pm 1.71,\, -5.13),(\pm 1.22,\, -5.46),(\pm 0.9,\, -5.62),(\pm 0.4,\, -5.80),(0,\, -5.85) \}$
#
# Assume origin as the center of first circle.

# %% [markdown]
# ### Given points array

# %%
points = np.array([(0, 5),
 (0.356, 4.987),
 (0.66, 4.96),
 (0.98, 4.9),
 (1.27, 4.84),
 (2.3, 6),
 (2.6, 7.1),
 (3.33, 8.49),
 (3.91, 8.79),
 (4.48, 8.95),
 (5.22, 8.99),
 (5.9, 8.86),
 (6.68, 8.48),
 (7.25, 7.98),
 (7.64, 7.41),
 (7.9, 6.76),
 (8, 6),
 (7.86, 5.11),
 (7.2, 3.96),
 (5.55, 3.05),
 (4.5, 2.18),
 (4.65, 1.82),
 (4.81, 1.37),
 (4.9, 0.98),
 (4.96, 0.66),
 (4.99, 0.36),
 (5, 0),
 (4.99, -0.36),
 (4.96, -0.66),
 (4.9, -0.98),
 (4.81, -1.37),
 (5.12, -1.66),
 (5.2, -2.04),
 (5.06, -2.63),
 (4.79, -3.11),
 (4.55, -3.41),
 (4.28, -3.66),
 (3.99, -3.87),
 (3.68, -4.05),
 (3.29, -4.18),
 (3, -4.21),
 (2.87, -4.3),
 (2.6, -4.48),
 (2.33, -4.67),
 (2.14, -4.81),
 (1.71, -5.13),
 (1.22, -5.46),
 (0.9, -5.62),
 (0.4, -5.8),
 (0, -5.85),
 (-0.4, -5.8),
 (-0.9, -5.62),
 (-1.22, -5.46),
 (-1.71, -5.13),
 (-2.14, -4.81),
 (-2.33, -4.67),
 (-2.6, -4.48),
 (-2.87, -4.3),
 (-3, -4.21),
 (-3.29, -4.18),
 (-3.68, -4.05),
 (-3.99, -3.87),
 (-4.28, -3.66),
 (-4.55, -3.41),
 (-4.79, -3.11),
 (-5.06, -2.63),
 (-5.2, -2.04),
 (-5.12, -1.66),
 (-4.81, -1.37),
 (-4.9, -0.98),
 (-4.96, -0.66),
 (-4.99, -0.36),
 (-5, 0),
 (-4.99, 0.36),
 (-4.96, 0.66),
 (-4.9, 0.98),
 (-4.81, 1.37),
 (-4.65, 1.82),
 (-4.5, 2.18),
 (-5.55, 3.05),
 (-7.2, 3.96),
 (-7.86, 5.11),
 (-8, 6),
 (-7.9, 6.76),
 (-7.64, 7.41),
 (-7.25, 7.98),
 (-6.68, 8.48),
 (-5.9, 8.86),
 (-5.22, 8.99),
 (-4.48, 8.95),
 (-3.91, 8.79),
 (-3.33, 8.49),
 (-2.6, 7.3),
 (-2.3, 6),
 (-1.27, 4.84),
 (-0.98, 4.9),
 (-0.66, 4.96),
 (-0.356, 4.987)])

len(points)
# Out:
# 98

# %% [markdown]
# ### 2.1) Plot the points using matplotlib. What shape did you noticed ?

# %% [markdown]
# ### 2.2) Plot the epicyclic approximation of this shape. Assume all the points of this shape are (xn,yn) means there are n circles having radii $R_i$, angular frequency $w_i$ and phase $\phi_i$ (from i = 1 to n) representing the given shape
#
# $$
# x_n = \sum_{i=1}^{n} R_i \cos(\omega_i t + \phi_i), \qquad
# y_n = \sum_{i=1}^{n} R_i \sin(\omega_i t + \phi_i)
# $$
#
# We can generalize it as a complex number
#
# $$z_n = \sum_{i=1}^n R_i e^{ j (\omega_i t + \phi_i) } = \sum_{i=1}^n C_i e^{ j (\omega_i t)}$$
#
# where  $j = \sqrt{-1}$   and   $C_ie^{j \omega_i t}$ represents a circle of radii $R_i$, angular frequency $w_i$ and phase $\phi_i$

# %% [markdown]
# ## Hints Q2
# It will be difficult to derive the formula to calculate $C_i$ for each term. So, here's the in built function for that. (It requires the knowledge of Fourier transforms which some of you will study in 2nd year and its currently out of scope)

# %%
# First convert each point into a complex number then use the below code to calculate R_i , w_i and phi_i via C_i
# N = 98 drones
C = np.fft.fft(z)/N #where z is the array of complex numbers of points
w = 2*np.pi*(np.fft.fftfreq(N, d=1/N))
#Ri is magnitude of Ci
#phi_i is angle of Ci
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # First convert each point into a complex number then use the below code to calculate R_i , w_i and phi_i via C_i
#       2 # N = 98 drones
# ----> 3 C = np.fft.fft(z)/N #where z is the array of complex numbers of points
#       4 w = 2*np.pi*(np.fft.fftfreq(N, d=1/N))
#       5 #Ri is magnitude of Ci
#       6 #phi_i is angle of Ci
#
# NameError: name 'z' is not defined

# %% [markdown]
# ## Your Solution 2

# %%
import numpy as np
import matplotlib.pyplot as plt
points = np.array([
    (0, 5), (0.356, 4.987), (0.66, 4.96), (0.98, 4.9), (1.27, 4.84), (2.3, 6), (2.6, 7.1), (3.33, 8.49), (3.91, 8.79), (4.48, 8.95), (5.22, 8.99), (5.9, 8.86), (6.68, 8.48), (7.25, 7.98), (7.64, 7.41), (7.9, 6.76), (8, 6), (7.86, 5.11), (7.2, 3.96), (5.55, 3.05), (4.5, 2.18), (4.65, 1.82), (4.81, 1.37), (4.9, 0.98), (4.96, 0.66), (4.99, 0.36), (5, 0), (4.99, -0.36), (4.96, -0.66), (4.9, -0.98), (4.81, -1.37), (5.12, -1.66), (5.2, -2.04), (5.06, -2.63), (4.79, -3.11), (4.55, -3.41), (4.28, -3.66), (3.99, -3.87), (3.68, -4.05), (3.29, -4.18), (3, -4.21), (2.87, -4.3), (2.6, -4.48), (2.33, -4.67), (2.14, -4.81), (1.71, -5.13), (1.22, -5.46), (0.9, -5.62), (0.4, -5.8), (0, -5.85), (-0.4, -5.8), (-0.9, -5.62), (-1.22, -5.46), (-1.71, -5.13), (-2.14, -4.81), (-2.33, -4.67), (-2.6, -4.48), (-2.87, -4.3), (-3, -4.21), (-3.29, -4.18), (-3.68, -4.05), (-3.99, -3.87), (-4.28, -3.66), (-4.55, -3.41), (-4.79, -3.11), (-5.06, -2.63), (-5.2, -2.04), (-5.12, -1.66), (-4.81, -1.37), (-4.9, -0.98), (-4.96, -0.66), (-4.99, -0.36), (-5, 0), (-4.99, 0.36), (-4.96, 0.66), (-4.9, 0.98), (-4.81, 1.37), (-4.65, 1.82), (-4.5, 2.18), (-5.55, 3.05), (-7.2, 3.96), (-7.86, 5.11), (-8, 6), (-7.9, 6.76), (-7.64, 7.41), (-7.25, 7.98), (-6.68, 8.48), (-5.9, 8.86), (-5.22, 8.99), (-4.48, 8.95), (-3.91, 8.79), (-3.33, 8.49), (-2.6, 7.3), (-2.3, 6), (-1.27, 4.84), (-0.98, 4.9), (-0.66, 4.96), (-0.356, 4.987)
])
N = len(points)
x = points[:, 0]
y = points[:, 1]

plt.plot(x, y, 'o', markersize=1)
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

points = np.array([
    (0, 5), (0.356, 4.987), (0.66, 4.96), (0.98, 4.9), (1.27, 4.84), (2.3, 6), (2.6, 7.1), (3.33, 8.49), (3.91, 8.79), (4.48, 8.95), (5.22, 8.99), (5.9, 8.86), (6.68, 8.48), (7.25, 7.98), (7.64, 7.41), (7.9, 6.76), (8, 6), (7.86, 5.11), (7.2, 3.96), (5.55, 3.05), (4.5, 2.18), (4.65, 1.82), (4.81, 1.37), (4.9, 0.98), (4.96, 0.66), (4.99, 0.36), (5, 0), (4.99, -0.36), (4.96, -0.66), (4.9, -0.98), (4.81, -1.37), (5.12, -1.66), (5.2, -2.04), (5.06, -2.63), (4.79, -3.11), (4.55, -3.41), (4.28, -3.66), (3.99, -3.87), (3.68, -4.05), (3.29, -4.18), (3, -4.21), (2.87, -4.3), (2.6, -4.48), (2.33, -4.67), (2.14, -4.81), (1.71, -5.13), (1.22, -5.46), (0.9, -5.62), (0.4, -5.8), (0, -5.85), (-0.4, -5.8), (-0.9, -5.62), (-1.22, -5.46), (-1.71, -5.13), (-2.14, -4.81), (-2.33, -4.67), (-2.6, -4.48), (-2.87, -4.3), (-3, -4.21), (-3.29, -4.18), (-3.68, -4.05), (-3.99, -3.87), (-4.28, -3.66), (-4.55, -3.41), (-4.79, -3.11), (-5.06, -2.63), (-5.2, -2.04), (-5.12, -1.66), (-4.81, -1.37), (-4.9, -0.98), (-4.96, -0.66), (-4.99, -0.36), (-5, 0), (-4.99, 0.36), (-4.96, 0.66), (-4.9, 0.98), (-4.81, 1.37), (-4.65, 1.82), (-4.5, 2.18), (-5.55, 3.05), (-7.2, 3.96), (-7.86, 5.11), (-8, 6), (-7.9, 6.76), (-7.64, 7.41), (-7.25, 7.98), (-6.68, 8.48), (-5.9, 8.86), (-5.22, 8.99), (-4.48, 8.95), (-3.91, 8.79), (-3.33, 8.49), (-2.6, 7.3), (-2.3, 6), (-1.27, 4.84), (-0.98, 4.9), (-0.66, 4.96), (-0.356, 4.987)
])

N = len(points)
x = points[:, 0]
y = points[:, 1]
z = x + 1j * y

C = np.fft.fft(z) / N
w = 2 * np.pi * np.fft.fftfreq(N, d=1/N)

num_circles = N 

T = 1.0
t = np.linspace(0, T, 500)

def epicycle_approximation(t_val, C_coeffs, w_freqs, N_terms):
    z_hat = np.zeros_like(t_val, dtype=complex)

    indices = np.argsort(np.abs(C_coeffs))[::-1]
    C_sorted = C_coeffs[indices[:N_terms]]
    w_sorted = w_freqs[indices[:N_terms]]

    for C_i, w_i in zip(C_sorted, w_sorted):
        z_hat += C_i * np.exp(1j * w_i * t_val)
        
    return z_hat

z_approx = epicycle_approximation(t, C, w, num_circles)
x_approx = z_approx.real
y_approx = z_approx.imag

plt.figure(figsize=(7, 7))
plt.plot(x, y, 'o', markersize=3, label='Original Points', color='black', alpha=0.5)
plt.plot(x_approx, y_approx, '-', linewidth=2, label='Epicycle Approximation', color='red')
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# ## Question 3
# The energy required to get from point $\vec{r}_1$ to point $\vec{r}_2$ for a drone is given by
#
# $$ E = \alpha \int_{C} \left| \frac{d\vec{r}}{dt} \right| dt - \int_C \vec{F} \cdot \frac{d\vec{r}}{dt}dt $$

# %% [markdown]
# 3.1) Suppose that $\alpha=5$ and our start and ends points are $\vec{r}_1 = (0,0)$ and $\vec{r}_2 = (0, 10)$. On this particular day, the wind produces a force field $\vec{F} = (0, -2/(x+1)^2)$. Approximate the optimal value of $A$ (A>0) in $\vec{r}(t) = A\sin(\pi t/10)\hat{x} + t\hat{y}$ that minimizes the **work** using only numpy arrays .

# %% [markdown]
# 3.2) Plot Energy as a function of A . (E(A) v/s A ) ? (Comment about its shape)

# %% [markdown]
# ## Your Solution 3

# %%
A_values = np.linspace(0.01, 5.0, 100)  

def calculate_energy(A):
    t = np.linspace(0.0, 10, 1000, endpoint=True)
    
    x = A * np.sin(np.pi * t / 10)
    
    vx = A * (np.pi / 10) * np.cos(np.pi * t / 10)
    vy = np.ones_like(t) 
    arclength_integrand = np.sqrt(vx**2 + vy**2)

    fy = -2.0 / (x + 1.0)**2
    work_integrand = fy * vy 

    L = np.trapezoid(arclength_integrand, t)
    W = np.trapezoid(work_integrand, t)

    E = 5 * L - W
    return E

energy_values = np.array([calculate_energy(A) for A in A_values])

min_E_index = np.argmin(energy_values)
optimal_A = A_values[min_E_index]

print(f"A that minimizes Energy : A = {optimal_A:.4f}")
# Out:
# A that minimizes Energy : A = 1.4213

# %%
A_values = np.linspace(0.01, 5.0, 100)  

def calculate_energy(A):
    t = np.linspace(0.0, 10, 1000, endpoint=True)
    
    x = A * np.sin(np.pi * t / 10)
    
    vx = A * (np.pi / 10) * np.cos(np.pi * t / 10)
    vy = np.ones_like(t) 
    arclength_integrand = np.sqrt(vx**2 + vy**2)

    fy = -2.0 / (x + 1.0)**2
    work_integrand = fy * vy 

    L = np.trapezoid(arclength_integrand, t)
    W = np.trapezoid(work_integrand, t)

    E = 5 * L - W
    return E

energy_values = np.array([calculate_energy(A) for A in A_values])

min_E_index = np.argmin(energy_values)
optimal_A = A_values[min_E_index]
min_E = energy_values[min_E_index]

plt.figure(figsize=(8, 6))
plt.plot(A_values, energy_values, label=r'E(A)')
plt.plot(optimal_A, min_E, 'ro', label=r'Minimum E(A) at A = ' + f'{optimal_A:.2f}')
plt.xlabel(r'Amplitude A')
plt.ylabel(r'Energy E(A)')
plt.legend()
plt.show()

# %% [markdown]
# ## Question 4
#
# You decide to install a series of camera drones along a straight path to spy on a suspicious person located at marker 31
#
# You buy four drones and they are evenly spaced starting from mile marker 16 and ending on mile marker 25.
#
# You buy another four drones starting on mile marker 29 and ending on mile marker 34. (also evenly spaced)
#
# A drone can face only one direction at a time.
# In order, from marker 16 to 34, each drone's orientation : N,S,E,W,S,E,W,N. (where N,S,E,W are cardinal directions)
#
# Determine how far each drone facing E is from the person? (Solve using Numpy only)

# %% [markdown]
# ## Your Solution 4

# %%
import numpy as np

markers_g1 = np.linspace(16, 25, 4)
markers_g2 = np.linspace(29, 34, 4)
all_markers = np.concatenate((markers_g1, markers_g2))

orientations = np.array(['N', 'S', 'E', 'W', 'S', 'E', 'W', 'N'])
target_marker = 31

mask_east = (orientations == 'E')
markers_east = all_markers[mask_east]
distances_to_person = np.abs(markers_east - target_marker)

print(f"Distances of 'E' drones from the person (marker 31): {distances_to_person}")
# Out:
# Distances of 'E' drones from the person (marker 31): [9.         0.33333333]
